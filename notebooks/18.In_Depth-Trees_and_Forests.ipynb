# %% [markdown]
# # In Depth - Decision Trees and Forests

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Here we'll explore a class of algorithms based on decision trees.
# Decision trees at their root are extremely intuitive.  They
# encode a series of "if" and "else" choices, similar to how a person might make a decision.
# However, which questions to ask, and how to proceed for each answer is entirely learned from the data.
#
# For example, if you wanted to create a guide to identifying an animal found in nature, you
# might ask the following series of questions:
#
# - Is the animal bigger or smaller than a meter long?
#     + *bigger*: does the animal have horns?
#         - *yes*: are the horns longer than ten centimeters?
#         - *no*: is the animal wearing a collar
#     + *smaller*: does the animal have two or four legs?
#         - *two*: does the animal have wings?
#         - *four*: does the animal have a bushy tail?
#
# and so on.  This binary splitting of questions is the essence of a decision tree.

# %% [markdown]
# One of the main benefit of tree-based models is that they require little preprocessing of the data.
# They can work with variables of different types (continuous and discrete) and are invariant to scaling of the features.
#
# Another benefit is that tree-based models are what is called "nonparametric", which means they don't have a fix set of parameters to learn. Instead, a tree model can become more and more flexible, if given more data.
# In other words, the number of free parameters grows with the number of samples and is not fixed, as for example in linear models.

# %% [markdown]
# ## Decision Tree Regression

# %% [markdown]
# A decision tree is a simple binary classification tree that is
# similar to nearest neighbor classification.  It can be used as follows:

# %%
from figures import make_dataset
x, y = make_dataset()
X = x.reshape(-1, 1)

plt.figure()
plt.xlabel('Feature X')
plt.ylabel('Target y')
plt.scatter(X, y);
# Out:
# /Users/uksrivastava/anaconda/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# <img src="data:image/png;base64,..." width="640">

# %%
from sklearn.tree import DecisionTreeRegressor

reg = DecisionTreeRegressor(max_depth=5)
reg.fit(X, y)

X_fit = np.linspace(-3, 3, 1000).reshape((-1, 1))
y_fit_1 = reg.predict(X_fit)

plt.figure()
plt.plot(X_fit.ravel(), y_fit_1, color='blue', label="prediction")
plt.plot(X.ravel(), y, '.k', label="training data")
plt.legend(loc="best");
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# A single decision tree allows us to estimate the signal in a non-parametric way,
# but clearly has some issues.  In some regions, the model shows high bias and
# under-fits the data.
# (seen in the long flat lines which don't follow the contours of the data),
# while in other regions the model shows high variance and over-fits the data
# (reflected in the narrow spikes which are influenced by noise in single points).

# %% [markdown]
# Decision Tree Classification
# ==================
# Decision tree classification work very similarly, by assigning all points within a leaf the majority class in that leaf:

# %%
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from figures import plot_2d_separator


X, y = make_blobs(centers=[[0, 0], [1, 1]], random_state=61526, n_samples=100)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

clf = DecisionTreeClassifier(max_depth=5)
clf.fit(X_train, y_train)

plt.figure()
plot_2d_separator(clf, X, fill=True)
plt.scatter(X_train[:, 0], X_train[:, 1], c=np.array(['b', 'r'])[y_train], s=60, alpha=.7, edgecolor='k')
plt.scatter(X_test[:, 0], X_test[:, 1], c=np.array(['b', 'r'])[y_test], s=60, edgecolor='k');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# There are many parameter that control the complexity of a tree, but the one that might be easiest to understand is the maximum depth. This limits how finely the tree can partition the input space, or how many "if-else" questions can be asked before deciding which class a sample lies in.
#
# This parameter is important to tune for trees and tree-based models. The interactive plot below shows how underfit and overfit looks like for this model. Having a ``max_depth`` of 1 is clearly an underfit model, while a depth of 7 or 8 clearly overfits. The maximum depth a tree can be grown at for this dataset is 8, at which point each leave only contains samples from a single class. This is known as all leaves being "pure."
#
# In the interactive plot below, the regions are assigned blue and red colors to indicate the predicted class for that region. The shade of the color indicates the predicted probability for that class (darker = higher probability), while yellow regions indicate an equal predicted probability for either class.

# %%
# %matplotlib inline
from figures import plot_tree_interactive
plot_tree_interactive()

# %% [markdown]
# Decision trees are fast to train, easy to understand, and often lead to interpretable models. However, single trees often tend to overfit the training data. Playing with the slider above you might notice that the model starts to overfit even before it has a good separation between the classes.
#
# Therefore, in practice it is more common to combine multiple trees to produce models that generalize better. The most common methods for combining trees are random forests and gradient boosted trees.

# %% [markdown]
# ## Random Forests

# %% [markdown]
# Random forests are simply many trees, built on different random subsets (drawn with replacement) of the data, and using different random subsets (drawn without replacement) of the features for each split.
# This makes the trees different from each other, and makes them overfit to different aspects. Then, their predictions are averaged, leading to a smoother estimate that overfits less.

# %%
from figures import plot_forest_interactive
plot_forest_interactive()

# %% [markdown]
# ## Selecting the Optimal Estimator via Cross-Validation

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import load_digits
from sklearn.ensemble import RandomForestClassifier

digits = load_digits()
X, y = digits.data, digits.target

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

rf = RandomForestClassifier(n_estimators=200)
parameters = {'max_features':['sqrt', 'log2', 10],
              'max_depth':[5, 7, 9]}

clf_grid = GridSearchCV(rf, parameters, n_jobs=-1)
clf_grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'max_features': ['sqrt', 'log2', 10], 'max_depth': [5, 7, 9]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
clf_grid.score(X_train, y_train)
# Out:
# 1.0

# %%
clf_grid.score(X_test, y_test)
# Out:
# 0.9733333333333334

# %% [markdown]
# ## Another option: Gradient Boosting

# %% [markdown]
# Another Ensemble method that can be useful is *Boosting*: here, rather than
# looking at 200 (say) parallel estimators, We construct a chain of 200 estimators
# which iteratively refine the results of the previous estimator.
# The idea is that by sequentially applying very fast, simple models, we can get a
# total model error which is better than any of the individual pieces.

# %%
from sklearn.ensemble import GradientBoostingRegressor
clf = GradientBoostingRegressor(n_estimators=100, max_depth=5, learning_rate=.2)
clf.fit(X_train, y_train)

print(clf.score(X_train, y_train))
print(clf.score(X_test, y_test))
# Out:
# 0.9974946138581186
# 0.8545796540943905

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE: Cross-validating Gradient Boosting</b>:
#      <ul>
#       <li>
#       Use a grid search to optimize the `learning_rate` and `max_depth` for a Gradient Boosted
# Decision tree on the digits data set.
#       </li>
#     </ul>
# </div>

# %%
from sklearn.datasets import load_digits
from sklearn.ensemble import GradientBoostingClassifier

digits = load_digits()
X_digits, y_digits = digits.data, digits.target

# split the dataset, apply grid-search
X_train, X_test, y_train, y_test = train_test_split(X_digits,y_digits,random_state = 1234)
params = {'learning_rate':[0.01,0.1,1.0,10],
            'max_depth':[1,2,5,8,10]}
clf = GridSearchCV(GradientBoostingClassifier(), param_grid=params, n_jobs=-1)
clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'learning_rate': [0.01, 0.1, 1.0, 10], 'max_depth': [1, 2, 5, 8, 10]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
print(clf.score(X_train, y_train), clf.score(X_test, y_test))
# Out:
# 1.0 0.9644444444444444

# %%
clf.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 2}

# %%
# %load solutions/18_gbc_grid.py
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier

digits = load_digits()
X_digits, y_digits = digits.data, digits.target
X_digits_train, X_digits_test, y_digits_train, y_digits_test = train_test_split(X_digits, y_digits, random_state=1)

param_grid = {'learning_rate': [0.01, 0.1, 0.1, 0.5, 1.0],
              'max_depth':[1, 3, 5, 7, 9]}

grid = GridSearchCV(GradientBoostingClassifier(), param_grid=param_grid, cv=5, verbose=3)
grid.fit(X_digits_train, y_digits_train)
print('Best score for GradientBoostingClassifier: {}'.format(grid.score(X_digits_test, y_digits_test)))
print('Best parameters for GradientBoostingClassifier: {}'.format(grid.best_params_))
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] learning_rate=0.01, max_depth=1 .................................
# [CV]  learning_rate=0.01, max_depth=1, score=0.7664233576642335, total=   1.3s
# [CV] learning_rate=0.01, max_depth=1 .................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [CV]  learning_rate=0.01, max_depth=1, score=0.7269372693726938, total=   1.1s
# [CV] learning_rate=0.01, max_depth=1 .................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.5s remaining:    0.0s
# [CV]  learning_rate=0.01, max_depth=1, score=0.7509293680297398, total=   1.3s
# [CV] learning_rate=0.01, max_depth=1 .................................
# [CV]  learning_rate=0.01, max_depth=1, score=0.7340823970037453, total=   1.8s
# [CV] learning_rate=0.01, max_depth=1 .................................
# [CV]  learning_rate=0.01, max_depth=1, score=0.7894736842105263, total=   1.3s
# [CV] learning_rate=0.01, max_depth=3 .................................
# [CV]  learning_rate=0.01, max_depth=3, score=0.9087591240875912, total=   3.9s
# [CV] learning_rate=0.01, max_depth=3 .................................
# [CV]  learning_rate=0.01, max_depth=3, score=0.8671586715867159, total=   3.9s
# [CV] learning_rate=0.01, max_depth=3 .................................
# [CV]  learning_rate=0.01, max_depth=3, score=0.9144981412639405, total=   3.4s
# [CV] learning_rate=0.01, max_depth=3 .................................
# [CV]  learning_rate=0.01, max_depth=3, score=0.8614232209737828, total=   3.9s
# [CV] learning_rate=0.01, max_depth=3 .................................
# [CV]  learning_rate=0.01, max_depth=3, score=0.9135338345864662, total=   3.9s
# [CV] learning_rate=0.01, max_depth=5 .................................
# [CV]  learning_rate=0.01, max_depth=5, score=0.8941605839416058, total=   8.4s
# [CV] learning_rate=0.01, max_depth=5 .................................
# [CV]  learning_rate=0.01, max_depth=5, score=0.8929889298892989, total=   7.4s
# [CV] learning_rate=0.01, max_depth=5 .................................
# [CV]  learning_rate=0.01, max_depth=5, score=0.9219330855018587, total=   7.2s
# [CV] learning_rate=0.01, max_depth=5 .................................
# [CV]  learning_rate=0.01, max_depth=5, score=0.8838951310861424, total=   7.7s
# [CV] learning_rate=0.01, max_depth=5 .................................
# [CV]  learning_rate=0.01, max_depth=5, score=0.9285714285714286, total=   9.0s
# [CV] learning_rate=0.01, max_depth=7 .................................
# [CV]  learning_rate=0.01, max_depth=7, score=0.8686131386861314, total=  10.3s
# [CV] learning_rate=0.01, max_depth=7 .................................
# [CV]  learning_rate=0.01, max_depth=7, score=0.8708487084870848, total=   9.3s
# [CV] learning_rate=0.01, max_depth=7 .................................
# [CV]  learning_rate=0.01, max_depth=7, score=0.895910780669145, total=  10.6s
# [CV] learning_rate=0.01, max_depth=7 .................................
# [CV]  learning_rate=0.01, max_depth=7, score=0.846441947565543, total=  10.8s
# [CV] learning_rate=0.01, max_depth=7 .................................
# [CV]  learning_rate=0.01, max_depth=7, score=0.868421052631579, total=  10.2s
# [CV] learning_rate=0.01, max_depth=9 .................................
# [CV]  learning_rate=0.01, max_depth=9, score=0.843065693430657, total=   6.7s
# [CV] learning_rate=0.01, max_depth=9 .................................
# [CV]  learning_rate=0.01, max_depth=9, score=0.8560885608856088, total=   8.6s
# [CV] learning_rate=0.01, max_depth=9 .................................
# [CV]  learning_rate=0.01, max_depth=9, score=0.8884758364312267, total=   7.4s
# [CV] learning_rate=0.01, max_depth=9 .................................
# [CV]  learning_rate=0.01, max_depth=9, score=0.8389513108614233, total=   8.3s
# [CV] learning_rate=0.01, max_depth=9 .................................
# [CV]  learning_rate=0.01, max_depth=9, score=0.8233082706766918, total=   7.5s
# [CV] learning_rate=0.1, max_depth=1 ..................................
# [CV]  learning_rate=0.1, max_depth=1, score=0.9014598540145985, total=   1.4s
# [CV] learning_rate=0.1, max_depth=1 ..................................
# [CV]  learning_rate=0.1, max_depth=1, score=0.933579335793358, total=   1.3s
# [CV] learning_rate=0.1, max_depth=1 ..................................
# [CV]  learning_rate=0.1, max_depth=1, score=0.9814126394052045, total=   1.3s
# [CV] learning_rate=0.1, max_depth=1 ..................................
# [CV]  learning_rate=0.1, max_depth=1, score=0.9213483146067416, total=   1.3s
# [CV] learning_rate=0.1, max_depth=1 ..................................
# [CV]  learning_rate=0.1, max_depth=1, score=0.9210526315789473, total=   1.6s
# [CV] learning_rate=0.1, max_depth=3 ..................................
# [CV]  learning_rate=0.1, max_depth=3, score=0.9452554744525548, total=   3.1s
# [CV] learning_rate=0.1, max_depth=3 ..................................
# [CV]  learning_rate=0.1, max_depth=3, score=0.940959409594096, total=   3.1s
# [CV] learning_rate=0.1, max_depth=3 ..................................
# [CV]  learning_rate=0.1, max_depth=3, score=0.9739776951672863, total=   3.1s
# [CV] learning_rate=0.1, max_depth=3 ..................................
# [CV]  learning_rate=0.1, max_depth=3, score=0.9588014981273408, total=   3.1s
# [CV] learning_rate=0.1, max_depth=3 ..................................
# [CV]  learning_rate=0.1, max_depth=3, score=0.9586466165413534, total=   3.0s
# [CV] learning_rate=0.1, max_depth=5 ..................................
# [CV]  learning_rate=0.1, max_depth=5, score=0.9343065693430657, total=   3.4s
# [CV] learning_rate=0.1, max_depth=5 ..................................
# [CV]  learning_rate=0.1, max_depth=5, score=0.940959409594096, total=   3.5s
# [CV] learning_rate=0.1, max_depth=5 ..................................
# [CV]  learning_rate=0.1, max_depth=5, score=0.9479553903345725, total=   3.5s
# [CV] learning_rate=0.1, max_depth=5 ..................................
# [CV]  learning_rate=0.1, max_depth=5, score=0.9325842696629213, total=   3.5s
# [CV] learning_rate=0.1, max_depth=5 ..................................
# [CV]  learning_rate=0.1, max_depth=5, score=0.9398496240601504, total=   3.5s
# [CV] learning_rate=0.1, max_depth=7 ..................................
# [CV]  learning_rate=0.1, max_depth=7, score=0.8941605839416058, total=   4.0s
# [CV] learning_rate=0.1, max_depth=7 ..................................
# [CV]  learning_rate=0.1, max_depth=7, score=0.922509225092251, total=   3.6s
# [CV] learning_rate=0.1, max_depth=7 ..................................
# [CV]  learning_rate=0.1, max_depth=7, score=0.9182156133828996, total=   3.9s
# [CV] learning_rate=0.1, max_depth=7 ..................................
# [CV]  learning_rate=0.1, max_depth=7, score=0.8951310861423221, total=   3.8s
# [CV] learning_rate=0.1, max_depth=7 ..................................
# [CV]  learning_rate=0.1, max_depth=7, score=0.9135338345864662, total=   3.9s
# [CV] learning_rate=0.1, max_depth=9 ..................................
# [CV]  learning_rate=0.1, max_depth=9, score=0.8941605839416058, total=   3.6s
# [CV] learning_rate=0.1, max_depth=9 ..................................
# [CV]  learning_rate=0.1, max_depth=9, score=0.9040590405904059, total=   3.8s
# [CV] learning_rate=0.1, max_depth=9 ..................................
# [CV]  learning_rate=0.1, max_depth=9, score=0.9330855018587361, total=   3.7s
# [CV] learning_rate=0.1, max_depth=9 ..................................
# [CV]  learning_rate=0.1, max_depth=9, score=0.8876404494382022, total=   3.7s
# [CV] learning_rate=0.1, max_depth=9 ..................................
# [CV]  learning_rate=0.1, max_depth=9, score=0.8909774436090225, total=   3.7s
# [CV] learning_rate=0.1, max_depth=1 ..................................
# [CV]  learning_rate=0.1, max_depth=1, score=0.9014598540145985, total=   1.2s
# [CV] learning_rate=0.1, max_depth=1 ..................................
# [CV]  learning_rate=0.1, max_depth=1, score=0.933579335793358, total=   1.1s
# [CV] learning_rate=0.1, max_depth=1 ..................................
# [CV]  learning_rate=0.1, max_depth=1, score=0.9814126394052045, total=   1.1s
# [CV] learning_rate=0.1, max_depth=1 ..................................
# [CV]  learning_rate=0.1, max_depth=1, score=0.9213483146067416, total=   1.2s
# [CV] learning_rate=0.1, max_depth=1 ..................................
# [CV]  learning_rate=0.1, max_depth=1, score=0.9210526315789473, total=   1.2s
# [CV] learning_rate=0.1, max_depth=3 ..................................
# [CV]  learning_rate=0.1, max_depth=3, score=0.9452554744525548, total=   3.0s
# [CV] learning_rate=0.1, max_depth=3 ..................................
# [CV]  learning_rate=0.1, max_depth=3, score=0.948339483394834, total=   3.1s
# [CV] learning_rate=0.1, max_depth=3 ..................................
# [CV]  learning_rate=0.1, max_depth=3, score=0.9739776951672863, total=   3.3s
# [CV] learning_rate=0.1, max_depth=3 ..................................
# [CV]  learning_rate=0.1, max_depth=3, score=0.9588014981273408, total=   3.1s
# [CV] learning_rate=0.1, max_depth=3 ..................................
# [CV]  learning_rate=0.1, max_depth=3, score=0.9624060150375939, total=   3.1s
# [CV] learning_rate=0.1, max_depth=5 ..................................
# [CV]  learning_rate=0.1, max_depth=5, score=0.9343065693430657, total=   3.4s
# [CV] learning_rate=0.1, max_depth=5 ..................................
# [CV]  learning_rate=0.1, max_depth=5, score=0.940959409594096, total=   3.8s
# [CV] learning_rate=0.1, max_depth=5 ..................................
# [CV]  learning_rate=0.1, max_depth=5, score=0.9591078066914498, total=   4.4s
# [CV] learning_rate=0.1, max_depth=5 ..................................
# [CV]  learning_rate=0.1, max_depth=5, score=0.9213483146067416, total=   3.8s
# [CV] learning_rate=0.1, max_depth=5 ..................................
# [CV]  learning_rate=0.1, max_depth=5, score=0.9360902255639098, total=   3.9s
# [CV] learning_rate=0.1, max_depth=7 ..................................
# [CV]  learning_rate=0.1, max_depth=7, score=0.8905109489051095, total=   4.6s
# [CV] learning_rate=0.1, max_depth=7 ..................................
# [CV]  learning_rate=0.1, max_depth=7, score=0.9188191881918819, total=   4.6s
# [CV] learning_rate=0.1, max_depth=7 ..................................
# [CV]  learning_rate=0.1, max_depth=7, score=0.9144981412639405, total=   4.8s
# [CV] learning_rate=0.1, max_depth=7 ..................................
# [CV]  learning_rate=0.1, max_depth=7, score=0.8876404494382022, total=   3.7s
# [CV] learning_rate=0.1, max_depth=7 ..................................
# [CV]  learning_rate=0.1, max_depth=7, score=0.9210526315789473, total=   3.8s
# [CV] learning_rate=0.1, max_depth=9 ..................................
# [CV]  learning_rate=0.1, max_depth=9, score=0.8941605839416058, total=   3.6s
# [CV] learning_rate=0.1, max_depth=9 ..................................
# [CV]  learning_rate=0.1, max_depth=9, score=0.9040590405904059, total=   4.6s
# [CV] learning_rate=0.1, max_depth=9 ..................................
# [CV]  learning_rate=0.1, max_depth=9, score=0.9330855018587361, total=   3.7s
# [CV] learning_rate=0.1, max_depth=9 ..................................
# [CV]  learning_rate=0.1, max_depth=9, score=0.8876404494382022, total=   3.7s
# [CV] learning_rate=0.1, max_depth=9 ..................................
# [CV]  learning_rate=0.1, max_depth=9, score=0.9060150375939849, total=   3.8s
# [CV] learning_rate=0.5, max_depth=1 ..................................
# [CV]  learning_rate=0.5, max_depth=1, score=0.927007299270073, total=   1.3s
# [CV] learning_rate=0.5, max_depth=1 ..................................
# [CV]  learning_rate=0.5, max_depth=1, score=0.959409594095941, total=   1.1s
# [CV] learning_rate=0.5, max_depth=1 ..................................
# [CV]  learning_rate=0.5, max_depth=1, score=0.9776951672862454, total=   1.1s
# [CV] learning_rate=0.5, max_depth=1 ..................................
# [CV]  learning_rate=0.5, max_depth=1, score=0.9138576779026217, total=   1.1s
# [CV] learning_rate=0.5, max_depth=1 ..................................
# [CV]  learning_rate=0.5, max_depth=1, score=0.9360902255639098, total=   1.1s
# [CV] learning_rate=0.5, max_depth=3 ..................................
# [CV]  learning_rate=0.5, max_depth=3, score=0.9379562043795621, total=   1.1s
# [CV] learning_rate=0.5, max_depth=3 ..................................
# [CV]  learning_rate=0.5, max_depth=3, score=0.9520295202952029, total=   1.1s
# [CV] learning_rate=0.5, max_depth=3 ..................................
# [CV]  learning_rate=0.5, max_depth=3, score=0.9591078066914498, total=   1.2s
# [CV] learning_rate=0.5, max_depth=3 ..................................
# [CV]  learning_rate=0.5, max_depth=3, score=0.947565543071161, total=   1.1s
# [CV] learning_rate=0.5, max_depth=3 ..................................
# [CV]  learning_rate=0.5, max_depth=3, score=0.9473684210526315, total=   1.1s
# [CV] learning_rate=0.5, max_depth=5 ..................................
# [CV]  learning_rate=0.5, max_depth=5, score=0.9306569343065694, total=   1.2s
# [CV] learning_rate=0.5, max_depth=5 ..................................
# [CV]  learning_rate=0.5, max_depth=5, score=0.940959409594096, total=   1.2s
# [CV] learning_rate=0.5, max_depth=5 ..................................
# [CV]  learning_rate=0.5, max_depth=5, score=0.9479553903345725, total=   1.2s
# [CV] learning_rate=0.5, max_depth=5 ..................................
# [CV]  learning_rate=0.5, max_depth=5, score=0.9325842696629213, total=   1.2s
# [CV] learning_rate=0.5, max_depth=5 ..................................
# [CV]  learning_rate=0.5, max_depth=5, score=0.9548872180451128, total=   1.2s
# [CV] learning_rate=0.5, max_depth=7 ..................................
# [CV]  learning_rate=0.5, max_depth=7, score=0.9051094890510949, total=   1.3s
# [CV] learning_rate=0.5, max_depth=7 ..................................
# [CV]  learning_rate=0.5, max_depth=7, score=0.915129151291513, total=   1.4s
# [CV] learning_rate=0.5, max_depth=7 ..................................
# [CV]  learning_rate=0.5, max_depth=7, score=0.9219330855018587, total=   1.3s
# [CV] learning_rate=0.5, max_depth=7 ..................................
# [CV]  learning_rate=0.5, max_depth=7, score=0.9138576779026217, total=   1.3s
# [CV] learning_rate=0.5, max_depth=7 ..................................
# [CV]  learning_rate=0.5, max_depth=7, score=0.924812030075188, total=   1.3s
# [CV] learning_rate=0.5, max_depth=9 ..................................
# [CV]  learning_rate=0.5, max_depth=9, score=0.9051094890510949, total=   1.4s
# [CV] learning_rate=0.5, max_depth=9 ..................................
# [CV]  learning_rate=0.5, max_depth=9, score=0.915129151291513, total=   1.4s
# [CV] learning_rate=0.5, max_depth=9 ..................................
# [CV]  learning_rate=0.5, max_depth=9, score=0.9144981412639405, total=   1.4s
# [CV] learning_rate=0.5, max_depth=9 ..................................
# [CV]  learning_rate=0.5, max_depth=9, score=0.8913857677902621, total=   1.4s
# [CV] learning_rate=0.5, max_depth=9 ..................................
# [CV]  learning_rate=0.5, max_depth=9, score=0.9060150375939849, total=   1.4s
# [CV] learning_rate=1.0, max_depth=1 ..................................
# [CV]  learning_rate=1.0, max_depth=1, score=0.19343065693430658, total=   1.1s
# [CV] learning_rate=1.0, max_depth=1 ..................................
# [CV]  learning_rate=1.0, max_depth=1, score=0.0996309963099631, total=   1.1s
# [CV] learning_rate=1.0, max_depth=1 ..................................
# [CV]  learning_rate=1.0, max_depth=1, score=0.10408921933085502, total=   1.1s
# [CV] learning_rate=1.0, max_depth=1 ..................................
# [CV]  learning_rate=1.0, max_depth=1, score=0.18352059925093633, total=   1.1s
# [CV] learning_rate=1.0, max_depth=1 ..................................
# [CV]  learning_rate=1.0, max_depth=1, score=0.18796992481203006, total=   1.1s
# [CV] learning_rate=1.0, max_depth=3 ..................................
# [CV]  learning_rate=1.0, max_depth=3, score=0.9452554744525548, total=   1.0s
# [CV] learning_rate=1.0, max_depth=3 ..................................
# [CV]  learning_rate=1.0, max_depth=3, score=0.9372693726937269, total=   2.2s
# [CV] learning_rate=1.0, max_depth=3 ..................................
# [CV]  learning_rate=1.0, max_depth=3, score=0.9479553903345725, total=   1.0s
# [CV] learning_rate=1.0, max_depth=3 ..................................
# [CV]  learning_rate=1.0, max_depth=3, score=0.9026217228464419, total=   0.9s
# [CV] learning_rate=1.0, max_depth=3 ..................................
# [CV]  learning_rate=1.0, max_depth=3, score=0.9135338345864662, total=   0.9s
# [CV] learning_rate=1.0, max_depth=5 ..................................
# [CV]  learning_rate=1.0, max_depth=5, score=0.9087591240875912, total=   0.9s
# [CV] learning_rate=1.0, max_depth=5 ..................................
# [CV]  learning_rate=1.0, max_depth=5, score=0.8966789667896679, total=   0.9s
# [CV] learning_rate=1.0, max_depth=5 ..................................
# [CV]  learning_rate=1.0, max_depth=5, score=0.9256505576208178, total=   1.1s
# [CV] learning_rate=1.0, max_depth=5 ..................................
# [CV]  learning_rate=1.0, max_depth=5, score=0.8689138576779026, total=   0.9s
# [CV] learning_rate=1.0, max_depth=5 ..................................
# [CV]  learning_rate=1.0, max_depth=5, score=0.9135338345864662, total=   0.9s
# [CV] learning_rate=1.0, max_depth=7 ..................................
# [CV]  learning_rate=1.0, max_depth=7, score=0.8905109489051095, total=   0.9s
# [CV] learning_rate=1.0, max_depth=7 ..................................
# [CV]  learning_rate=1.0, max_depth=7, score=0.9114391143911439, total=   0.9s
# [CV] learning_rate=1.0, max_depth=7 ..................................
# [CV]  learning_rate=1.0, max_depth=7, score=0.8810408921933085, total=   1.0s
# [CV] learning_rate=1.0, max_depth=7 ..................................
# [CV]  learning_rate=1.0, max_depth=7, score=0.9063670411985019, total=   0.9s
# [CV] learning_rate=1.0, max_depth=7 ..................................
# [CV]  learning_rate=1.0, max_depth=7, score=0.9172932330827067, total=   1.2s
# [CV] learning_rate=1.0, max_depth=9 ..................................
# [CV]  learning_rate=1.0, max_depth=9, score=0.9233576642335767, total=   1.0s
# [CV] learning_rate=1.0, max_depth=9 ..................................
# [CV]  learning_rate=1.0, max_depth=9, score=0.915129151291513, total=   1.0s
# [CV] learning_rate=1.0, max_depth=9 ..................................
# [CV]  learning_rate=1.0, max_depth=9, score=0.9107806691449815, total=   1.0s
# [CV] learning_rate=1.0, max_depth=9 ..................................
# [CV]  learning_rate=1.0, max_depth=9, score=0.9138576779026217, total=   1.1s
# [CV] learning_rate=1.0, max_depth=9 ..................................
# [CV]  learning_rate=1.0, max_depth=9, score=0.924812030075188, total=   1.0s
# [Parallel(n_jobs=1)]: Done 125 out of 125 | elapsed:  6.2min finished
# Best score for GradientBoostingClassifier: 0.9555555555555556
# Best parameters for GradientBoostingClassifier: {'learning_rate': 0.1, 'max_depth': 3}

# %% [markdown]
# ## Feature importance
#
# Both RandomForest and GradientBoosting objects expose a `feature_importances_` attribute when fitted. This attribute is one of the most powerful feature of these models. They basically quantify how much each feature contributes to gain in performance in the nodes of the different trees.

# %%
X, y = X_digits[y_digits < 2], y_digits[y_digits < 2]

rf = RandomForestClassifier(n_estimators=300, n_jobs=1)
rf.fit(X, y)
print(rf.feature_importances_)  # one value per feature
# Out:
# [0.00000000e+00 3.53502062e-05 1.12010413e-03 3.79643655e-03
#  9.42897443e-04 3.27512048e-03 2.57354619e-03 0.00000000e+00
#  0.00000000e+00 9.58772169e-04 1.88724353e-02 9.45213902e-04
#  5.97696920e-03 2.72569590e-03 1.29263312e-04 0.00000000e+00
#  2.56793848e-04 1.26229852e-02 5.36216571e-03 3.53847700e-02
#  6.42086770e-02 3.80456943e-03 5.45309962e-03 0.00000000e+00
#  2.99724653e-04 6.39787248e-03 7.56003015e-04 6.38582171e-02
#  1.27724083e-01 3.97033489e-03 6.18998055e-02 0.00000000e+00
#  0.00000000e+00 2.35119673e-02 3.30440871e-03 3.09678617e-02
#  1.74800763e-01 6.40113272e-03 1.05144645e-01 0.00000000e+00
#  0.00000000e+00 3.51277592e-02 2.17262296e-02 7.61726912e-03
#  6.64861162e-02 5.21820541e-03 3.16593223e-02 0.00000000e+00
#  0.00000000e+00 2.94157399e-04 3.27579852e-02 2.48598962e-03
#  4.48987099e-04 2.06905880e-03 1.03666457e-04 7.20291567e-05
#  0.00000000e+00 3.69403233e-05 2.19808015e-03 8.83481323e-03
#  8.21801299e-04 1.67940646e-03 1.20292632e-03 1.67757289e-03]

# %%
plt.figure()
plt.imshow(rf.feature_importances_.reshape(8, 8), interpolation='nearest')
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">
